# %%
import requests
import nyckel
import base64
import os
import csv
from dotenv import load_dotenv

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
CLIENT_SECRET = os.getenv("CLIENT_SECRET")

# Get access token
response = requests.post(
    "https://www.nyckel.com/connect/token",
    headers={"Content-Type": "application/x-www-form-urlencoded"},
    data={
        "grant_type": "client_credentials",
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET
    }
)

access_token = response.json()["access_token"]
print("Access Token:", access_token)
# Out:
# Access Token: eyJhbGciOiJSUzI1NiIsInR5cCI6ImF0K2p3dCJ9.eyJpc3MiOiJodHRwczovL3d3dy5ueWNrZWwuY29tIiwibmJmIjoxNzY1MjUzNjc3LCJpYXQiOjE3NjUyNTM2NzcsImV4cCI6MTc2NTI1NzI3Nywic2NvcGUiOlsiYXBpIl0sImNsaWVudF9pZCI6ImlzYXc2dGxjYzRtaGFyazRtOGJwbHp2ajcybmhweTRsIiwianRpIjoiQkYyMkJFMDU2QzM2REJBQUVDOENFRUNEMEZCQTg1QTgifQ.cN0H5RGKsPSWkoC3PI5lqd9WuPYHF69EgJY02opsABkNew6KPD4k5QmWNj3kAknbGftC7RxNVtrg-odwYH7tlgA8gZgrfqNmRlRdzWWHX6DF79sROA1dCF8pmGj6sCruvcgjpW1CBkZqQJQi7VEVljRO53vvLIDwXDSMBCO4tvszN-BKIpX9KmVjeO5oo4hALDV1Fle9oxeOUZte3eIbKu2VQFs0eeTc5UzC4W8WEXk2vS4SiMUq_9EvOdZPZ4agpoc7pdl43ozMKVrPgaajVXp7icwvBaqL-OKayO0bXMRnAQRMjIxv98p05IhgFJu6Moyx7z4VMAzdIGt3wwHa2g

# %%
# Credentials
credentials = nyckel.Credentials(client_id=CLIENT_ID,
                                 client_secret=CLIENT_SECRET)

def labeling(image_folder):
    # Dictionary to store results
    results = {}

    for filename in os.listdir(image_folder):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            file_path = os.path.join(image_folder, filename)
            
            # Read and convert to base64
            with open(file_path, "rb") as f:
                img_bytes = f.read()
            img_base64 = "data:image/jpeg;base64," + base64.b64encode(img_bytes).decode("utf-8")
            
            # Invoke Nyckel Gender Detector
            response = nyckel.invoke("gender-detector", img_base64, credentials)
            
            # Save result
            results[filename] = {
                "label": response["labelName"],
                "confidence": response["confidence"]
            }
    return results

def print_results(results):
    # Print results
    for img, info in results.items():
        print(f"{img}: {info['label']} (Confidence: {info['confidence']:.2f})")



def storing_results_csv(results, name):
    # Store results in CSV
    with open(name, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["Image", "Gender", "Confidence"])
        for img, info in results.items():
            writer.writerow([img, info["label"], info["confidence"]])

# %%
folders = ["ChatGPT", "ChatGPT_faces", "Midjourney", "Midjourney_faces"]

for folder in folders:
    results = labeling(folder)
    name = "gender_labels_" + folder + ".csv"
    storing_results_csv(results, name)
    print(folder + " labeled")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 4
#       1 folders = ["ChatGPT", "ChatGPT_faces", "Midjourney", "Midjourney_faces"]
#       3 for folder in folders:
# ----> 4     results = labeling(folder)
#       5     name = "gender_labels_" + folder + ".csv"
#       6     storing_results_csv(results, name)
#
# Cell In[2], line 23, in labeling(image_folder)
#      19         response = nyckel.invoke("gender-detector", img_base64, credentials)
#      21         # Save result
#      22         results[filename] = {
# ---> 23             "label": response["labelName"],
#      24             "confidence": response["confidence"]
#      25         }
#      26 return results
#
# KeyError: 'labelName'

# %%
folder = "Stable Diffusion_faces"

results = labeling(folder)
name = "gender_labels_" + folder + ".csv"
storing_results_csv(results, name)
print(folder + " labeled")
# Out:
# Stable Diffusion_faces labeled

# %%
folder = "Stable Diffusion for labeling"

results = labeling(folder)
name = "gender_labels_Stable_Diffusion.csv"
storing_results_csv(results, name)
print(folder + " labeled")
# Out:
# Stable Diffusion for labeling labeled
